# %%
# !pip3 install numpy scipy pandas matplotlib
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import pylab
import scipy.stats
df = pd.read_csv("data.csv")
pylab.style.use("ggplot")

# %%
def get_options(name):
    return list(df[name].drop_duplicates())

# %%
sorted(get_options("N"))
# Out:
# [5000, 10000, 30000, 60000, 100000, 200000, 400000, 1200000, 1900000, 2500000]

# %%
def filter(**args):
    res = pd.DataFrame(df)
    for i in args.keys():
        res = res[res[i]==args[i]]
    return res

# %%
print(get_options("N"))
print(get_options("r"))
print(get_options("len"))
# Out:
# [100000, 10000, 1200000, 1900000, 200000, 2500000, 30000, 400000, 5000, 60000]
# [0.0, 0.05, 0.06, 0.07, 0.08, 0.09, 0.1, 0.11, 0.12, 0.13, 0.14, 0.15, 0.16, 0.17]
# [10, 15, 20, 30]

# %%
frame = filter(len=30)
pylab.scatter(frame["Call Counts"],frame["Time"],alpha=0.5)
scipy.stats.linregress(frame["Call Counts"],frame["Time"])
# Out:
# LinregressResult(slope=0.07017005769515813, intercept=135.28192646241678, rvalue=0.9993240702985341, pvalue=0.0, stderr=9.770350338474842e-05, intercept_stderr=13.912864469439587)

# %%
frame = filter(r=0.17, len=10)
pylab.scatter(frame["N"],frame["Time"],alpha=0.5)

# %%
ran = np.array([5000, 10000, 30000, 60_000, 100_000, 200_000, 400_000, 1_200_000, 1_900_000, 2_500_000])
RAM = pd.read_csv("ram.csv")
pylab.scatter(ran[RAM["JobID"]], RAM["MaxRSS"]) 
pylab.ylabel("MAX RAM USED (KB)")
# Out:
# Text(0, 0.5, 'MAX RAM USED (KB)')
